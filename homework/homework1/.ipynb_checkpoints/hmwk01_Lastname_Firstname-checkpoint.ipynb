# %% [markdown]
# # Homework 1: Data Cleaning and Exploratory Data Analysis
# ***
#
# **Name**:
#
# ***
#
# This assignment is due on Moodle by **5pm on Friday February 2nd**. Your solutions to theoretical questions should be done in Markdown directly below the associated question.  Your solutions to computational questions should include any specified Python code and results as well as written commentary on your conclusions.  Remember that you are encouraged to discuss the problems with your classmates, but **you must write all code and solutions on your own**.
#
# **NOTES**:
#
# - Unless a url is given for a data set, you will find the required data in the same directory as this assignment on GitHub.
# - If you're not familiar with typesetting math directly into Markdown then by all means, do your work on paper first and then typeset it later.  Remember that there is a [reference guide](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) linked on Piazza on writing math in Markdown.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from pandas import DataFrame
# %matplotlib inline

# %% [markdown]
# ### Problem 1
# ***
#
# An owner of an animal sanctuary wants to estimate her sanctuary's average food consumption over the next year in order to estimate the future food costs. Her sanctuary comprises 75 pandas, 25 otters, 50 buffalo, and 50 owls. The owner pops open her SanctuaryTrackr App's Current Resident List, randomly selects 24 animals from it, and tracks their food consumptions in pounds per day (lbs/day) over the next week. So as to get a good estimate, she intentionally selects 9 pandas, 3 otters, 6 buffalo, and 6 owls.
#
# Identify the following:
#
# - the population
# - the sample frame
# - the sample
# - the type of sample
# - the quantity of interest

# %% [markdown]
# Population: Animals in the sanctuary
#
# Sample frame: SantuaryTrackr App
#
# Sample: 24 animals, 9 pandas, 3 otters, 6 buffalo, 6 owls. (3 per 25 animals of each type)
#
# Type of sample: Stratified sample
#
# Quality of interest: food consumption

# %% [markdown]
# ### Problem 2
# ***
#
# A method to investigate the sensitivity of the sample mean and the sample median to extreme outliers is to replace one or more elements in a given dataset by a number $y$ and investigate the eﬀect when $y$ goes to inﬁnity. To illustrate this, consider the dataset
#
# $$
# 4.6 \quad
# 5.0 \quad
# 6.5 \quad
# 7.7 \quad
# 3.2 \quad
# 4.2 \quad
# 3.0 \quad
# 6.6
# $$
#
# **Part A**: Compute the sample mean and sample median.

# %%
df = pd.DataFrame({"y": [4.6, 5.0, 6.5, 7.7, 3.2, 4.2, 3.0, 6.6]})
mean = df["y"].mean()
median = df["y"].median()
print("mean {}".format(mean))
print("median {}".format(median))
# Out:
# mean 5.1000000000000005
# median 4.8

# %% [markdown]
# **Part B**: We replace the element $5.0$ by some real number $q$. What happens with the sample mean and the sample median of this new dataset as $q \rightarrow -\infty$?

# %%
df = pd.DataFrame({"y": [4.6, -110, 6.5, 7.7, 3.2, 4.2, 3.0, 6.6]})
mean = df["y"].mean()
median = df["y"].median()
print("mean {}".format(mean))
print("median {}".format(median))
# Out:
# mean -9.275
# median 4.4

# %% [markdown]
# The median is initially affected since 5.0 was used in the median calculation. However, as we trend to $-\infty$ we find that the $mean \rightarrow -\infty$ while the median is unaffected by further decreasing $q$

# %% [markdown]
# **Part C**: We replace a number of elements by some real number $q$. How many elements do we need to replace so that the sample median of the new dataset goes to infinity as $q \rightarrow -\infty$?

# %% [markdown]
# If even, we need only change the first half of the elements
# If odd, we need to change m+1 elements where m = n/2

# %% [markdown]
# **Part D**: Suppose we have another data set of size $n$. How many elements do we need to replace by some real number $q$, so that the sample mean of the new dataset diverges as $q \rightarrow -\infty$? And how many elements do we need to replace, so that the sample median of the new dataset goes to infinity?

# %% [markdown]
# We only need to change a single element to cause the mean to trend towards $-\infty$

# %% [markdown]
# ### Problem 3
# ***
#
# Let $x_1, x_2, \ldots, x_n$ be $n$ observations of a variable of interest.  Recall that the sample mean $\bar{x}_n$ and sample variance $s^2_n$ are given by
#
# $$
# \bar{x}_n = \frac{1}{n}\sum_{k=1}^n x_k \quad \textrm{and} \quad s^2_n = \frac{1}{n-1}\sum_{k=1}^n \left( x_k - \bar{x}_n\right)^2
# $$
#
# where here the subscript $n$'s indicate the number of observations in the sample. Notice that a natural computation of the variance requires two passes over the data: one to compute the mean, and a second to subtract the mean from each observation and compute the sum of squares. It is often useful to be able to compute the variance in a single pass, inspecting each value $x_k$ only once; for example, when the data are being collected without enough storage to keep all the values, or when costs of memory access dominate those of computation. In this problem you will explore two methods for such an _online_ computation of the mean and variance.
#
# **Part A**: Show algebraically that the following relation holds between the mean of the first $n-1$ observations and the mean of all $n$ observations:
#
# $$
# \bar{x}_n = \bar{x}_{n-1} + \frac{x_n - \bar{x}_{n-1}}{n}
# $$

# %% [markdown]
# $$
# \frac{1}{n}\sum_{k=1}^n x_k \quad = \bar{x}_{n-1} + \frac{x_n - \bar{x}_{n-1}}{n}
# $$

# %% [markdown]
# **Part B**: Write a function `my_sample_mean` that takes as its input a numpy array and returns the mean of that numpy array using the formulas from class (written above). You may *not* use numpy's built in mean function. Write another function `my_sample_var` that takes as its input a numpy array and returns the variance of that numpy array, again using the formulas from class (written above). You may *not* use any built-in sample variance functions.

# %%
def my_sample_mean(a):
    sum=0
    for item in a:
        sum += item
    mean = 1/len(a) * sum
    return(mean)
    
def my_sample_var(a):
    mean = my_sample_mean(a)
    sumsq=0
    for item in a:
        sumsq += (item - mean)**2
    var = 1/(len(a)-1) * sumsq
    var = var**(1/2)
    return(var)

# %%
a = np.array([2,3,4])
print("mean: {}".format(my_sample_mean(a)))
print("var: {}".format(my_sample_var(a)))
# Out:
# mean: 3.0
# var: 1.0

# %% [markdown]
# **Part C**: Use your functions from Part B to compute the sample mean and sample variance of the following array.
#
# `otter_weights = [25, 29, 40, 19, 7, 6, 3, 12, 19, 21, 22, 45, 27]`

# %%
otter_weights = [25, 29, 40, 19, 7, 6, 3, 12, 19, 21, 22, 45, 27]
print("mean: {}".format(my_sample_mean(otter_weights)))
print("var: {}".format(my_sample_var(otter_weights)))
# Out:
# mean: 21.153846153846153
# var: 12.542236335984597

# %% [markdown]
# **Part D**: Implement a third function called `update_mean` that implements the formula whose valdity you proved in Part A. (Note: this function will need to take as its input three things: $x_n$, $\bar{x}_{n-1}$ and $n$.)
#
# Use this function to compute the values that you get from taking the mean of the first one otter, the first two otters, the first three otters, and so on up to all the otters. Store your otter means in a numpy array called `otterations`.

# %%
def update_mean(x, xm1, n):
    mean = xm1 + ((x-xm1)/n)
    return (mean)
prev_item=0.0
n=0
otterations = np.array([0.0]*len(otter_weights))
for item in otter_weights:
    otterations[n] = update_mean(item, prev_item, n+1)
    prev_item = otterations[n]
    n+=1
print("otterations: \n{}".format(otterations))
# Out:
# otterations:
# [ 25.          27.          31.33333333  28.25        24.          21.
#   18.42857143  17.625       17.77777778  18.1         18.45454545
#   20.66666667  21.15384615]

# %% [markdown]
# ### Problem 4
# ***
# Some claim that the final hours aboard the RMS Titanic were marked by class warfare; others claim it was characterized by male chivalry.  We have the data on survival rates by class and by sex, so let's figure out whether there is evidence for these scenarios. Access the titanic data in `titanic_data.csv` and store it in a Pandas DataFrame. The data contains information pertaining to class status (**Pclass**), survival of passengers (**Survived**), and gender (**Sex**), among others.

# %% [markdown]
# **Part A**: Consider the two claims: class warfare, and male chivalry. Suppose that class warfare occurred in the final hours aboard the Titanic.  What patterns might you expect to see in the data?  Suppose that male chivalry was widespread during the final hours instead. What patterns might you then expect to see in the data?  Explain both of these hypothesized patterns in words. Are these two hypotheses mutually exclusive or not?

# %% [markdown]
# I would expect the poorer people to survive since they are more resourceful. If male chivalry occurred then more women and children would have survived.

# %% [markdown]
# **Part B**: Create a clean data set by removing any rows from the DataFrame that are missing values corresponding to **Survived**, **Pclass**, **Age**, or **Sex**. Store the clean data in a DataFrame called dfTitanic.

# %%
local_path = 'titanic_data.csv'
df = pd.read_csv(local_path)
dfTitanic = df.loc[df.Survived.notnull() & df.Pclass.notnull() & df.Age.notnull() & df.Sex.notnull()]
dfTitanic.head(1000) #714 records are left after cleaning
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 10            11         1       3
# 11            12         0       1
# 13            14         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         0       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 36            37         1       3
# 37            38         0       3
# 39            40         1       3
# ..           ...       ...     ...
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  36.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  18.0      1
# 2                               Heikkinen, Miss. Laina  female  14.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  27.0      1
# 4                             Allen, Mr. William Henry    male  63.0      0
# 5                                     Moran, Mr. James    male  14.0      0
# 6                              McCarthy, Mr. Timothy J    male  39.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female  42.0      1
# 11                            Bonnell, Miss. Elizabeth  female  30.0      0
# 13                         Andersson, Mr. Anders Johan    male  43.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  19.0      0
# 16                                Rice, Master. Eugene    male  23.0      4
# 17                        Williams, Mr. Charles Eugene    male  45.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  16.0      1
# 19                             Masselmani, Mrs. Fatima  female  29.0      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  28.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  24.0      0
# 23                        Sloper, Mr. William Thompson    male  58.0      0
# 26                             Emir, Mr. Farred Chehab    male  22.0      0
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  30.0      0
# 29                                 Todoroff, Mr. Lalio    male  46.0      0
# 30                            Uruchurtu, Don. Manuel E    male  33.0      0
# 32                            Glynn, Miss. Mary Agatha  female  18.0      0
# 33                               Wheadon, Mr. Edward H    male  22.0      0
# 34                             Meyer, Mr. Edgar Joseph    male  23.5      1
# 35                      Holverson, Mr. Alexander Oskar    male  32.0      1
# 36                                    Mamee, Mr. Hanna    male  44.0      0
# 37                            Cann, Mr. Ernest Charles    male  53.0      0
# 39                         Nicola-Yarred, Miss. Jamila  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  16.0      0
# 859                                   Razi, Mr. Raihed    male  28.0      0
# 860                            Hansen, Mr. Claus Peter    male  29.0      2
# 861                        Giles, Mr. Frederick Edward    male   2.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  64.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  30.0      8
# 864                             Gill, Mr. John William    male   8.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  48.0      0
# 866                       Duran y More, Miss. Asuncion  female  19.0      1
# 867               Roebling, Mr. Washington Augustus II    male  50.0      0
# 868                        van Melkebeke, Mr. Philemon    male  37.0      0
# 869                    Johnson, Master. Harold Theodor    male   2.0      1
# 870                                  Balkic, Mr. Cerin    male  21.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  54.0      1
# 873                        Vander Cruyssen, Mr. Victor    male  65.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  29.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  25.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  50.0      0
# 877                               Petroff, Mr. Nedelio    male  38.0      0
# 878                                 Laleff, Mr. Kristo    male  18.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  39.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  22.0      0
# 881                                 Markun, Mr. Johann    male  36.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female   4.0      0
# 883                      Banfield, Mr. Frederick James    male  49.0      0
# 884                             Sutehall, Mr. Henry Jr    male  18.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  30.0      0
# 886                              Montvila, Rev. Juozas    male   4.0      0
# 887                       Graham, Miss. Margaret Edith  female  24.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  23.0      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# 5        0            330877   8.4583   NaN        Q
# 6        0             17463  51.8625   E46        S
# 10       1           PP 9549  16.7000    G6        S
# 11       0            113783  26.5500  C103        S
# 13       5            347082  31.2750   NaN        S
# 15       0            248706  16.0000   NaN        S
# 16       1            382652  29.1250   NaN        Q
# 17       0            244373  13.0000   NaN        S
# 18       0            345763  18.0000   NaN        S
# 19       0              2649   7.2250   NaN        C
# 20       0            239865  26.0000   NaN        S
# 21       0            248698  13.0000   D56        S
# 22       0            330923   8.0292   NaN        Q
# 23       0            113788  35.5000    A6        S
# 26       0              2631   7.2250   NaN        C
# 28       0            330959   7.8792   NaN        Q
# 29       0            349216   7.8958   NaN        S
# 30       0          PC 17601  27.7208   NaN        C
# 32       0            335677   7.7500   NaN        Q
# 33       0        C.A. 24579  10.5000   NaN        S
# 34       0          PC 17604  82.1708   NaN        C
# 35       0            113789  52.0000   NaN        S
# 36       0              2677   7.2292   NaN        C
# 37       0        A./5. 2152   8.0500   NaN        S
# 39       0              2651  11.2417   NaN        C
# ..     ...               ...      ...   ...      ...
# 858      3              2666  19.2583   NaN        C
# 859      0              2629   7.2292   NaN        C
# 860      0            350026  14.1083   NaN        S
# 861      0             28134  11.5000   NaN        S
# 862      0             17466  25.9292   D17        S
# 863      2          CA. 2343  69.5500   NaN        S
# 864      0            233866  13.0000   NaN        S
# 865      0            236852  13.0000   NaN        S
# 866      0     SC/PARIS 2149  13.8583   NaN        C
# 867      0          PC 17590  50.4958   A24        S
# 868      0            345777   9.5000   NaN        S
# 869      1            347742  11.1333   NaN        S
# 870      0            349248   7.8958   NaN        S
# 871      1             11751  52.5542   D35        S
# 873      0            345765   9.0000   NaN        S
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 876      0              7534   9.8458   NaN        S
# 877      0            349212   7.8958   NaN        S
# 878      0            349217   7.8958   NaN        S
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 881      0            349257   7.8958   NaN        S
# 882      0              7552  10.5167   NaN        S
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 884      0   SOTON/OQ 392076   7.0500   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [714 rows x 12 columns]

# %% [markdown]
# **Part C**: Determine the fraction of survivors from each passenger class.

# %%
Pclass1, Pclass2, Pclass3 = dfTitanic["Pclass"].value_counts()
# compare these entries, and give me back the survived column with those matches and sum it
sum1 = dfTitanic.loc[(dfTitanic["Survived"]) == 1 & (dfTitanic["Pclass"]==1), "Survived"].sum()
sum2 = dfTitanic.loc[(dfTitanic["Survived"]) == 1 & (dfTitanic["Pclass"]==2), "Survived"].sum()
sum3 = dfTitanic.loc[(dfTitanic["Survived"]) == 1 & (dfTitanic["Pclass"]==3), "Survived"].sum()
print("Pclass1 survivors: {}/{}={}%".format(sum1, Pclass1, 100*(sum1/Pclass1)))
print("Pclass2 survivors: {}/{}={}%".format(sum2, Pclass2, 100*(sum2/Pclass2)))
print("Pclass3 survivors: {}/{}={}%".format(sum3, Pclass3, 100*(sum3/Pclass3)))
# Out:
# Pclass1 survivors: 108/401=26.932668329177055%
# Pclass2 survivors: 70/168=41.66666666666667%
# Pclass3 survivors: 101/145=69.6551724137931%

# %% [markdown]
# **Part D**: Compute the fraction of survivors according to class and gender.  Did men in first class or women in third class have a higher survival rate?

# %%
msum1 = dfTitanic.loc[(dfTitanic["Survived"] == 1) & (dfTitanic["Pclass"]==1) & (dfTitanic["Sex"] == "male"), "Survived"].sum()
msum2 = dfTitanic.loc[(dfTitanic["Survived"] == 1) & (dfTitanic["Pclass"]==2) & (dfTitanic["Sex"] == "male"), "Survived"].sum()
msum3 = dfTitanic.loc[(dfTitanic["Survived"] == 1) & (dfTitanic["Pclass"]==3) & (dfTitanic["Sex"] == "male"), "Survived"].sum()
fsum1 = dfTitanic.loc[(dfTitanic["Survived"] == 1) & (dfTitanic["Pclass"]==1) & (dfTitanic["Sex"] == "female"), "Survived"].sum()
fsum2 = dfTitanic.loc[(dfTitanic["Survived"] == 1) & (dfTitanic["Pclass"]==2) & (dfTitanic["Sex"] == "female"), "Survived"].sum()
fsum3 = dfTitanic.loc[(dfTitanic["Survived"] == 1) & (dfTitanic["Pclass"]==3) & (dfTitanic["Sex"] == "female"), "Survived"].sum()
totalmsum1 = dfTitanic.loc[(dfTitanic["Pclass"]==1) & (dfTitanic["Sex"] == "male"), "Pclass"].sum()
totalmsum2 = dfTitanic.loc[(dfTitanic["Pclass"]==2) & (dfTitanic["Sex"] == "male"), "Pclass"].sum()/2
totalmsum3 = dfTitanic.loc[(dfTitanic["Pclass"]==3) & (dfTitanic["Sex"] == "male"), "Pclass"].sum()/3
totalfsum1 = dfTitanic.loc[(dfTitanic["Pclass"]==1) & (dfTitanic["Sex"] == "female"), "Pclass"].sum()
totalfsum2 = dfTitanic.loc[(dfTitanic["Pclass"]==2) & (dfTitanic["Sex"] == "female"), "Pclass"].sum()/2
totalfsum3 = dfTitanic.loc[(dfTitanic["Pclass"]==3) & (dfTitanic["Sex"] == "female"), "Pclass"].sum()/3

print("Male Pclass1 survivors: {}/{}={}%".format(msum1, totalmsum1, 100*(msum1/totalmsum1)))
print("Male Pclass2 survivors: {}/{}={}%".format(msum2, totalmsum2, 100*(msum2/totalmsum2)))
print("Male Pclass3 survivors: {}/{}={}%".format(msum3, totalmsum3, 100*(msum3/totalmsum3)))
print("Female Pclass1 survivors: {}/{}={}%".format(fsum1, totalfsum1, 100*(fsum1/totalfsum1)))
print("Female Pclass2 survivors: {}/{}={}%".format(fsum2, totalfsum2, 100*(fsum2/totalfsum2)))
print("Female Pclass3 survivors: {}/{}={}%".format(fsum3, totalfsum3, 100*(fsum3/totalfsum3)))
# Out:
# Male Pclass1 survivors: 36/93=38.70967741935484%
# Male Pclass2 survivors: 16/87.0=18.39080459770115%
# Male Pclass3 survivors: 39/283.0=13.780918727915195%
# Female Pclass1 survivors: 72/75=96.0%
# Female Pclass2 survivors: 54/58.0=93.10344827586206%
# Female Pclass3 survivors: 62/118.0=52.54237288135594%

# %% [markdown]
# **Part E**: How would you characterize the distribution of **AGE**? (By _characterize_ we mean that you should indicate whether the data are unimodal, bimodal, multimodal, symmetric, negatively skewed, positively skewed, etc.)  Make any necessary graphical summaries to justify your conclusion.

# %% [markdown]
# The histogram shows is that it is positively skewed since the mean is greater than the median. $Q1$ is also closer to the median than $Q3$

# %%
fig, ax = plt.subplots(figsize=(8,4))
dfTitanic.hist(column="Age", ax=ax)
dfTitanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# **Part F**: Were the median and mean ages for females who survived higher or lower than for females who did not survive?

# %% [markdown]
# The mean age for females that survived were lower than those that did not survive.

# %%
df["Female Survivors"] = dfTitanic.loc[(dfTitanic["Survived"]==1) & (dfTitanic["Sex"]=="female"), "Age"]
#fig, ax = plt.subplots(figsize=(8,4))
#df["Female Survivors"].hist()
df["Female Survivors"].describe()[['mean']]
# Out:
# mean    28.405585
# Name: Female Survivors, dtype: float64

# %%
df["Female Fatalities"] = dfTitanic.loc[(dfTitanic["Survived"]==0) & (dfTitanic["Sex"]=="female"), "Age"]
#fig, ax = plt.subplots(figsize=(8,4))
#df["Female Fatalities"].hist()
df["Female Fatalities"].describe()[['mean']]
# Out:
# mean    28.922063
# Name: Female Fatalities, dtype: float64

# %% [markdown]
# **Part G**: Do the data suggest class warfare, male chivalry, or some combination of both characteristics in the final hours aboard the Titanic?  Justify your conclusion based on the computations done above, or do any other analysis that you like, but be sure to clearly justify your conclusion.

# %% [markdown]
# Male chivalry: The survival rate of women was significantly higher than men in all classes with less than half of men in pclass 1 surviving while women in pclass 1 having a survival rate over 90%.
#
# Class warfare: It does appear that women in pclass1 were the most favored, while men from first class were least favored for survival. It could have been possible that some class warfare occured from the data, however, the sample size for Pclass 2 and Pclass 3 was much smaller than Pclass1 because their ages were known. Perhaps the data cleaning removed some results which might have helped here. Thus, class warfare was not as strong of a predictor as male chivalry.

# %% [markdown]
# ### Problem 5 - Not anotter homework problem! :(
# ***
#
# Otters are undisputedly one of nature's most awesome animals. From a cursory Google Image Search of *baby otter* or *otters holding hands* or *otters water slide* this is easy to demonstrate.
#
# Because the CS Department was able to pull a few strings, we have obtained a dataset of sea otter behavior. For each otter studied, the dataset contains:
#
# - **hhrecord**: the otter's personal record for hand-holding (hours; 999)
# - **pawsize**: the size of the otter's paw (unspecified units; 999)
# - **floatation**: boolean, indicating whether the otter displayed leadership in floatation. (9)
# - **satscore**: the otter's projected SAT score percentile. (unclear why this was included; 99)
# - **height**: otter's height (unspecified units; 99)
# - **weight**: otter's weight (unspecified units; 999)
# - **urchins**: boolean, indicating whether the otter was observed eating urchins (9)
#
# All these data are included in the whitespace-delimited file `otters.data`

# %% [markdown]
# **Part A**: Create a clean data set that removes subjects if any observations on the subject are unknown.  Note that that collectors of the data set used values like $9$, $99$, $999$, to denote unknown values. Those values are listed parenthetically in the description above Store the modified data set in a Pandas DataFrame called dfOtters.

# %%
data = pd.read_table("otters.data", delim_whitespace=True)
dfOtters =  data.loc[(data["hhrecord"] != 999) & (data["pawsize"] != 999) & (data["floatation"] != 9) & (data["satscore"] != 99) & (data["height"] != 99) & (data["weight"] != 999) & (data["urchins"] != 9)]
dfOtters.head()
# Out:
#    hhrecord  pawsize  floatation  satscore  height  weight  urchins
# 0       120      284           0        27      62     100        0
# 1       113      282           0        33      64     135        0
# 2       128      279           0        28      64     115        1
# 4       108      282           0        23      67     125        1
# 5       136      286           0        25      62      93        0

# %% [markdown]
# **Part B**: Use the information in dfOtters to create a density histogram of the hand-holding records of otters who do not eat sea urchins (urchins=0) and another histogram placed directly below the first in the same graphics device for the hand-holding records of otters who do eat urchins (urchins=1).  Make the range of the horizontal axis $30$ to $180$ (hours) for both histograms.  Make sure to give each subplot titles and label axes.

# %%
#not done
urchin = dfOtters.loc[(dfOtters["urchins"]==1), "hhrecord"]
no_urchin = dfOtters.loc[(dfOtters["urchins"]==0), "hhrecord"]
fig, ax = plt.subplots(figsize=(8,4))
plt.title("Hand holding records for otters")
plt.xlabel("hours")
plt.ylabel("count")
plt.hist([urchin, no_urchin], color=['b', 'r'], label = ["urchin", "no_urchin"], normed=[True, True])
plt.legend()
# Out:
# /home/sinner/miniconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# **Part C**: Based on the histograms in **Part B**, characterize the distribution of hand-holding records for both urchin and non-urchin eaters.

# %% [markdown]
# The distribution is right skewed for the urchin eating otters, and left skewed for otters that did not eat urchins. I normalized the graph above so we can see that otters that did not eat urchins have higher records for hand holding.

# %% [markdown]
# **Part D**: What are the mean and median hand-holding record differences between otters who eat urchins and otters who don't?  Can you think of any reason not to use the mean as a measure of center to compare records for this problem?

# %%
#pull median out of describe, and access that key, value pair :)
print("Urchin eating otters: mean = {} median = {}".format(my_sample_mean(urchin), urchin.describe()[["50%"]]["50%"]))
print("No-urchin eating otters: mean = {} median = {}".format(my_sample_mean(no_urchin), no_urchin.describe()[["50%"]]["50%"]))
# Out:
# Urchin eating otters: mean = 113.81917211328977 median = 115.0
# No-urchin eating otters: mean = 123.08531468531469 median = 123.0

# %% [markdown]
# The mean will tell us that generally the non urchin eating otters perform better at hand holding records. However, I think it is a poor way to describe this dataset because it appears that they are close. When looking at the histogram we can see that the records are much higher for non-urchin eating otters. To add to this, high records shouldn't be characterized by mean since they describe the top performance of the otters and not their average hand holding times. This seems off.

# %% [markdown]
# **Part E**: Create side-by-side box-and-whisker plots to compare the hand-holding records of otters who eat urchins and otters who do not.  Use the box-and-whisker plot conventions discussed in lecture.

# %%
fig, ax = plt.subplots(figsize=(8,8))
plt.boxplot([urchin, no_urchin])
# Out:
# /home/sinner/miniconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff9fbe20d68>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe2fa58>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff9fbe2a7f0>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe2ac50>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe35748>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe35ba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff9fbe2f550>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe3b4a8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff9fbe2f0f0>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe3b048>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff9fbe20ef0>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe2a3c8>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe2fe80>,
#   <matplotlib.lines.Line2D at 0x7ff9fbe352e8>]}

# %% [markdown]
# **Part F**: Using the box-and-whisker plots from **Part E** comment on the distributions of hand-holding records of otters within each urchin / non-urchin groups as well as the comparison of the two classes.

# %% [markdown]
# There is more outliers in the non_urchin group and they achieve longer hand holding records on average. The non-urchin set is more closely grouped around the median even though they have more outliers.

# %% [markdown]
# ### Problem 6: Cleaning Election Results Data
# ***
#
# The file 2014\_election\_results.csv contains data from congressional district races during the 2014 midterm elections.  The problem is that the data is **extremely dirty**.  Your goal in the problem will be to use Pandas to clean the election result data and then, if possible, determine the names of the winners in each congressional district as well as the vote percentage margin that they won by.  Remember that data cleaning and wrangling is a messy business.  Don't be afraid to roll your sleeves up and get hacky!
#
# **Part A**: Complete the clean_election_data( ) function to return a clean DataFrame that accomplishes the following:
#
# - remove rows in the DataFrame that are missing values in columns **STATE**, **D**, and/or **GENERAL PERCENT**
#
# <p> </p>
#
# - replace unknown names in **CANDIDATE NAME** with:
#     - the value from **CANDIDATE NAME (Last)**, if available
#     - the string "UNKNOWN" if impossible to determine the full or last name
#     - **Note**: besides "NaN", data collectors appear to have used the string "Scattered" to indicate missing names as well
# <p> </p>
# - convert the strings in **GENERAL PERCENT** to values of type float between $0$ and $100$
# <p> </p>
# - restrict the DataFrame to only the columns **STATE**, **D**, **CANDIDATE NAME**, **GENERAL PERCENT**

# %%
def clean_election_data():
    # read in dirty data 
    df = pd.read_csv("2014_election_results.csv")
    #replace empty data with np.nan
    df.replace('', np.nan, inplace=True)
    #drop row with np.nan in STATE, D, and GENERAL PERCENT
    df = df.loc[df['STATE'].notnull() & df['D'].notnull() & df['GENERAL PERCENT'].notnull()]
    #replace unknown names in CANDIDATE NAME
    
    #restrict columns data to columns, STATE, D, DANDIDATE NAME, GENERAL PERCENT 
    
    #remove drop rows that contain NaN data(all candidate data should be filled in by this point)
    
    
    
    return df
clean_election_data()
# Out:
# 2
#      STATE ABBREVIATION           STATE  D     FEC ID#  (I)  \
# 0                    AL         Alabama  1   H4AL01123  (I)
# 1                    AL         Alabama  1   H4AL01156  NaN
# 2                    AL         Alabama  1         NaN  NaN
# 5                    AL         Alabama  2   H0AL02087  (I)
# 6                    AL         Alabama  2   H4AL02071  NaN
# 7                    AL         Alabama  2         NaN  NaN
# 10                   AL         Alabama  3   H2AL03032  (I)
# 13                   AL         Alabama  3   H4AL03061  NaN
# 14                   AL         Alabama  3         NaN  NaN
# 17                   AL         Alabama  4   H6AL04098  (I)
# 18                   AL         Alabama  4         NaN  NaN
# 21                   AL         Alabama  5   H0AL05163  (I)
# 24                   AL         Alabama  5   H4AL05082  NaN
# 25                   AL         Alabama  5         NaN  NaN
# 28                   AL         Alabama  6   H4AL06098  NaN
# 36                   AL         Alabama  6   H4AL06148  NaN
# 38                   AL         Alabama  6         NaN  NaN
# 41                   AL         Alabama  7   H0AL07086  (I)
# 44                   AL         Alabama  7         NaN  NaN
# 50                   AK          Alaska  0   H6AK00045  (I)
# 55                   AK          Alaska  0   H4AK00123  NaN
# 58                   AK          Alaska  0   H2AK00143  NaN
# 60                   AK          Alaska  0         NaN  NaN
# 66                   AS  American Samoa  0   H4AS00036  NaN
# 67                   AS  American Samoa  0   H0AS00018  (I)
# 68                   AS  American Samoa  0   H4AS00085  NaN
# 69                   AS  American Samoa  0   H4AS00069  NaN
# 70                   AS  American Samoa  0   H8AS00052  NaN
# 71                   AS  American Samoa  0   H4AS00093  NaN
# 72                   AS  American Samoa  0   H2AS00030  NaN
# ...                 ...             ... ..         ...  ...
# 3612                 WI       Wisconsin  2         NaN  NaN
# 3615                 WI       Wisconsin  3   H6WI03099  (I)
# 3618                 WI       Wisconsin  3   H4WI03144  NaN
# 3620                 WI       Wisconsin  3   H4WI03136  NaN
# 3625                 WI       Wisconsin  3         NaN  NaN
# 3628                 WI       Wisconsin  4  H4WI04183   (I)
# 3632                 WI       Wisconsin  4   H0WI04090  NaN
# 3638                 WI       Wisconsin  4   H4WI04266  NaN
# 3639                 WI       Wisconsin  4         NaN  NaN
# 3642                 WI       Wisconsin  5  H8WI09050   (I)
# 3645                 WI       Wisconsin  5   H4WI05099  NaN
# 3650                 WI       Wisconsin  5         NaN  NaN
# 3653                 WI       Wisconsin  6  H4WI06048   NaN
# 3659                 WI       Wisconsin  6   H4WI06071  NaN
# 3662                 WI       Wisconsin  6   H4WI06113  NaN
# 3665                 WI       Wisconsin  6         NaN  NaN
# 3668                 WI       Wisconsin  7   H0WI07051  (I)
# 3671                 WI       Wisconsin  7   H4WI07103  NaN
# 3673                 WI       Wisconsin  7   H4WI07095  NaN
# 3677                 WI       Wisconsin  7   H4WI07111  NaN
# 3680                 WI       Wisconsin  7         NaN  NaN
# 3681                 WI       Wisconsin  7         NaN  NaN
# 3684                 WI       Wisconsin  8   H0WI08075  (I)
# 3687                 WI       Wisconsin  8   H4WI08077  NaN
# 3692                 WI       Wisconsin  8         NaN  NaN
# 3697                 WY         Wyoming  0   H8WY00148  (I)
# 3701                 WY         Wyoming  0   H4WY00170  NaN
# 3704                 WY         Wyoming  0   H2WY00125  NaN
# 3705                 WY         Wyoming  0   H2WY00133  NaN
# 3706                 WY         Wyoming  0         NaN  NaN
#
#      CANDIDATE NAME (First) CANDIDATE NAME (Last)  \
# 0                   Bradley                 Byrne
# 1                 Burton R.               LeFlore
# 2                       NaN                   NaN
# 5                    Martha                  Roby
# 6                     Erick                Wright
# 7                       NaN                   NaN
# 10                     Mike                Rogers
# 13                 Jesse T.                 Smith
# 14                      NaN                   NaN
# 17                   Robert              Aderholt
# 18                      NaN                   NaN
# 21                       Mo                Brooks
# 24                     Mark                  Bray
# 25                      NaN                   NaN
# 28                     Gary                Palmer
# 36                     Mark                Lester
# 38                      NaN                   NaN
# 41                 Terri A.                Sewell
# 44                      NaN                   NaN
# 50                      Don                 Young
# 55                 Forrest                 Dunbar
# 58                   Jim C.             McDermott
# 60                      NaN                   NaN
# 66                    Aumua                 Amata
# 67                Eni F. H.          Faleomavaega
# 68                  Togiola              Tulafono
# 69                  Mapu S.                Jamias
# 70      Rosie Fuala'au Tago             Lancaster
# 71                  Meleagi       Suitonu-Chapman
# 72                    Tuika                 Tuika
# ...                     ...                   ...
# 3612                    NaN             Scattered
# 3615                   Ron                   Kind
# 3618                   Tony                 Kurtz
# 3620                    Ken             Van Doren
# 3625                    NaN             Scattered
# 3628                   Gwen                 Moore
# 3632                    Dan               Sebring
# 3638              Robert R.               Raymond
# 3639                    NaN             Scattered
# 3642         F. James., Jr.         Sensenbrenner
# 3645                  Chris              Rockwood
# 3650                    NaN             Scattered
# 3653                 Glenn               Grothman
# 3659                Mark L.                Harris
# 3662                    Gus            Fahrendorf
# 3665                    NaN             Scattered
# 3668                   Sean                 Duffy
# 3671                   John               Schiess
# 3673                 Kelly               Westlund
# 3677               Lawrence                  Dale
# 3680                    Rob                Taylor
# 3681                    NaN             Scattered
# 3684                Reid J.                Ribble
# 3687                    Ron                Gruett
# 3692                    NaN             Scattered
# 3697                Cynthia                Lummis
# 3701                Richard               Grayson
# 3704                Richard              Brubaker
# 3705           Daniel Clyde              Cummings
# 3706                    NaN             Scattered
#
#                       CANDIDATE NAME TOTAL VOTES   PARTY  \
# 0                     Byrne, Bradley         NaN       R
# 1                 LeFlore, Burton R.         NaN       D
# 2                          Scattered         NaN       W
# 5                       Roby, Martha         NaN       R
# 6                                NaN         NaN       D
# 7                          Scattered         NaN       W
# 10                      Rogers, Mike         NaN       R
# 13                   Smith, Jesse T.         NaN       D
# 14                         Scattered         NaN       W
# 17                  Aderholt, Robert         NaN       R
# 18                         Scattered         NaN       W
# 21                        Brooks, Mo         NaN       R
# 24                        Bray, Mark         NaN     IND
# 25                         Scattered         NaN       W
# 28                      Palmer, Gary         NaN       R
# 36                    Lester, Mark #         NaN       D
# 38                         Scattered         NaN       W
# 41                  Sewell, Terri A.         NaN       D
# 44                         Scattered         NaN       W
# 50                        Young, Don         NaN       R
# 55                  Dunbar, Forrest          NaN       D
# 58                 McDermott, Jim C.         NaN     LIB
# 60                         Scattered         NaN       W
# 66                      Amata, Aumua         NaN       R
# 67           Faleomavaega, Eni F. H.         NaN       D
# 68                 Tulafono, Togiola         NaN       D
# 69                               NaN         NaN       D
# 70    Lancaster, Rosie Fuala'au Tago         NaN     IND
# 71          Suitonu-Chapman, Meleagi         NaN       D
# 72                      Tuika, Tuika         NaN     IND
# ...                              ...         ...     ...
# 3612                       Scattered         NaN       W
# 3615                      Kind, Ron          NaN       D
# 3618                     Kurtz, Tony         NaN       R
# 3620                             NaN         NaN     R/W
# 3625                       Scattered         NaN       W
# 3628                     Moore, Gwen         NaN       D
# 3632                             NaN         NaN       R
# 3638              Raymond, Robert R.         NaN     IND
# 3639                       Scattered         NaN       W
# 3642   Sensenbrenner, F. James., Jr.         NaN       R
# 3645                 Rockwood, Chris         NaN       D
# 3650                       Scattered         NaN       W
# 3653                Grothman, Glenn          NaN       R
# 3659                             NaN         NaN       D
# 3662                 Fahrendorf, Gus         NaN     LIB
# 3665                       Scattered         NaN       W
# 3668                     Duffy, Sean         NaN       R
# 3671                   Schiess, John         NaN  W(R)/W
# 3673                Westlund, Kelly          NaN       D
# 3677                  Dale, Lawrence         NaN     GRE
# 3680                     Taylor, Rob         NaN       W
# 3681                       Scattered         NaN       W
# 3684                 Ribble, Reid J.         NaN       R
# 3687                     Gruett, Ron         NaN       D
# 3692                       Scattered         NaN       W
# 3697                 Lummis, Cynthia         NaN       R
# 3701                Grayson, Richard         NaN       D
# 3704               Brubaker, Richard         NaN     LIB
# 3705          Cummings, Daniel Clyde         NaN     CON
# 3706                       Scattered         NaN       W
#
#                             ...                         RUNOFF VOTES RUNOFF %  \
# 0                           ...                                  NaN      NaN
# 1                           ...                                  NaN      NaN
# 2                           ...                                  NaN      NaN
# 5                           ...                                  NaN      NaN
# 6                           ...                                  NaN      NaN
# 7                           ...                                  NaN      NaN
# 10                          ...                                  NaN      NaN
# 13                          ...                                  NaN      NaN
# 14                          ...                                  NaN      NaN
# 17                          ...                                  NaN      NaN
# 18                          ...                                  NaN      NaN
# 21                          ...                                  NaN      NaN
# 24                          ...                                  NaN      NaN
# 25                          ...                                  NaN      NaN
# 28                          ...                               47,525   63,49%
# 36                          ...                                  NaN      NaN
# 38                          ...                                  NaN      NaN
# 41                          ...                                  NaN      NaN
# 44                          ...                                  NaN      NaN
# 50                          ...                                  NaN      NaN
# 55                          ...                                  NaN      NaN
# 58                          ...                                  NaN      NaN
# 60                          ...                                  NaN      NaN
# 66                          ...                                  NaN      NaN
# 67                          ...                                  NaN      NaN
# 68                          ...                                  NaN      NaN
# 69                          ...                                  NaN      NaN
# 70                          ...                                  NaN      NaN
# 71                          ...                                  NaN      NaN
# 72                          ...                                  NaN      NaN
# ...                         ...                                  ...      ...
# 3612                        ...                                  NaN      NaN
# 3615                        ...                                  NaN      NaN
# 3618                        ...                                  NaN      NaN
# 3620                        ...                                  NaN      NaN
# 3625                        ...                                  NaN      NaN
# 3628                        ...                                  NaN      NaN
# 3632                        ...                                  NaN      NaN
# 3638                        ...                                  NaN      NaN
# 3639                        ...                                  NaN      NaN
# 3642                        ...                                  NaN      NaN
# 3645                        ...                                  NaN      NaN
# 3650                        ...                                  NaN      NaN
# 3653                        ...                                  NaN      NaN
# 3659                        ...                                  NaN      NaN
# 3662                        ...                                  NaN      NaN
# 3665                        ...                                  NaN      NaN
# 3668                        ...                                  NaN      NaN
# 3671                        ...                                  NaN      NaN
# 3673                        ...                                  NaN      NaN
# 3677                        ...                                  NaN      NaN
# 3680                        ...                                  NaN      NaN
# 3681                        ...                                  NaN      NaN
# 3684                        ...                                  NaN      NaN
# 3687                        ...                                  NaN      NaN
# 3692                        ...                                  NaN      NaN
# 3697                        ...                                  NaN      NaN
# 3701                        ...                                  NaN      NaN
# 3704                        ...                                  NaN      NaN
# 3705                        ...                                  NaN      NaN
# 3706                        ...                                  NaN      NaN
#
#      GENERAL VOTES  GENERAL PERCENT GE RUNOFF ELECTION VOTES (LA)  \
# 0           103,758          68,16%                           NaN
# 1            48,278          31,71%                           NaN
# 2               198           0,13%                           NaN
# 5           113,103          67,34%                           NaN
# 6            54,692          32,56%                           NaN
# 7               157           0,09%                           NaN
# 10          103,558          66,12%                           NaN
# 13           52,816          33,72%                           NaN
# 14              246           0,16%                           NaN
# 17          132,831          98,57%                           NaN
# 18            1,921           1,43%                           NaN
# 21          115,338          74,42%                           NaN
# 24           39,005          25,17%                           NaN
# 25              631           0,41%                           NaN
# 28          135,945          76,18%                           NaN
# 36           42,291          23,70%                           NaN
# 38              213           0,12%                           NaN
# 41          133,687          98,37%                           NaN
# 44            2,212           1,63%                           NaN
# 50          142,572          50,97%                           NaN
# 55          114,602          40,97%                           NaN
# 58            21,29           7,61%                           NaN
# 60            1,277           0,46%                           NaN
# 66            4,306          42,03%                           NaN
# 67            3,157          30,81%                           NaN
# 68             1,13          11,03%                           NaN
# 69              652           6,36%                           NaN
# 70              268           2,62%                           NaN
# 71              229           2,24%                           NaN
# 72              201           1,96%                           NaN
# ...             ...             ...                           ...
# 3612            308           0,09%                           NaN
# 3615        155,368          56,46%                           NaN
# 3618         119,54          43,44%                           NaN
# 3620            128           0,05%                           NaN
# 3625            125           0,05%                           NaN
# 3628        179,045          70,24%                           NaN
# 3632          68,49          26,87%                           NaN
# 3638          7,002           2,75%                           NaN
# 3639            355           0,14%                           NaN
# 3642         231,16          69,45%                           NaN
# 3645         101,19          30,40%                           NaN
# 3650            476           0,14%                           NaN
# 3653        169,767          56,77%                           NaN
# 3659        122,212          40,87%                           NaN
# 3662          6,865           2,30%                           NaN
# 3665            189           0,06%                           NaN
# 3668        169,891          59,28%                           NaN
# 3671              5           0,00%                           NaN
# 3673        112,949          39,41%                           NaN
# 3677          3,686           1,29%                           NaN
# 3680             30           0,01%                           NaN
# 3681             42           0,01%                           NaN
# 3684        188,553          65,01%                           NaN
# 3687        101,345          34,94%                           NaN
# 3692            150           0,05%                           NaN
# 3697        113,038          68,47%                           NaN
# 3701         37,803          22,90%                           NaN
# 3704          7,112           4,31%                           NaN
# 3705          6,749           4,09%                           NaN
# 3706            398           0,24%                           NaN
#
#      GE RUNOFF ELECTION % (LA) COMBINED GE PARTY TOTALS (CT, NY, SC)  \
# 0                          NaN                                   NaN
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 5                          NaN                                   NaN
# 6                          NaN                                   NaN
# 7                          NaN                                   NaN
# 10                         NaN                                   NaN
# 13                         NaN                                   NaN
# 14                         NaN                                   NaN
# 17                         NaN                                   NaN
# 18                         NaN                                   NaN
# 21                         NaN                                   NaN
# 24                         NaN                                   NaN
# 25                         NaN                                   NaN
# 28                         NaN                                   NaN
# 36                         NaN                                   NaN
# 38                         NaN                                   NaN
# 41                         NaN                                   NaN
# 44                         NaN                                   NaN
# 50                         NaN                                   NaN
# 55                         NaN                                   NaN
# 58                         NaN                                   NaN
# 60                         NaN                                   NaN
# 66                         NaN                                   NaN
# 67                         NaN                                   NaN
# 68                         NaN                                   NaN
# 69                         NaN                                   NaN
# 70                         NaN                                   NaN
# 71                         NaN                                   NaN
# 72                         NaN                                   NaN
# ...                        ...                                   ...
# 3612                       NaN                                   NaN
# 3615                       NaN                                   NaN
# 3618                       NaN                                   NaN
# 3620                       NaN                                   NaN
# 3625                       NaN                                   NaN
# 3628                       NaN                                   NaN
# 3632                       NaN                                   NaN
# 3638                       NaN                                   NaN
# 3639                       NaN                                   NaN
# 3642                       NaN                                   NaN
# 3645                       NaN                                   NaN
# 3650                       NaN                                   NaN
# 3653                       NaN                                   NaN
# 3659                       NaN                                   NaN
# 3662                       NaN                                   NaN
# 3665                       NaN                                   NaN
# 3668                       NaN                                   NaN
# 3671                       NaN                                   NaN
# 3673                       NaN                                   NaN
# 3677                       NaN                                   NaN
# 3680                       NaN                                   NaN
# 3681                       NaN                                   NaN
# 3684                       NaN                                   NaN
# 3687                       NaN                                   NaN
# 3692                       NaN                                   NaN
# 3697                       NaN                                   NaN
# 3701                       NaN                                   NaN
# 3704                       NaN                                   NaN
# 3705                       NaN                                   NaN
# 3706                       NaN                                   NaN
#
#      COMBINED % (CT, NY, SC) GE WINNER INDICATOR  \
# 0                        NaN                   W
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 5                        NaN                   W
# 6                        NaN                 NaN
# 7                        NaN                 NaN
# 10                       NaN                   W
# 13                       NaN                 NaN
# 14                       NaN                 NaN
# 17                       NaN                   W
# 18                       NaN                 NaN
# 21                       NaN                   W
# 24                       NaN                 NaN
# 25                       NaN                 NaN
# 28                       NaN                   W
# 36                       NaN                 NaN
# 38                       NaN                 NaN
# 41                       NaN                   W
# 44                       NaN                 NaN
# 50                       NaN                   W
# 55                       NaN                 NaN
# 58                       NaN                 NaN
# 60                       NaN                 NaN
# 66                       NaN                   W
# 67                       NaN                 NaN
# 68                       NaN                 NaN
# 69                       NaN                 NaN
# 70                       NaN                 NaN
# 71                       NaN                 NaN
# 72                       NaN                 NaN
# ...                      ...                 ...
# 3612                     NaN                 NaN
# 3615                     NaN                   W
# 3618                     NaN                 NaN
# 3620                     NaN                 NaN
# 3625                     NaN                 NaN
# 3628                     NaN                   W
# 3632                     NaN                 NaN
# 3638                     NaN                 NaN
# 3639                     NaN                 NaN
# 3642                     NaN                   W
# 3645                     NaN                 NaN
# 3650                     NaN                 NaN
# 3653                     NaN                   W
# 3659                     NaN                 NaN
# 3662                     NaN                 NaN
# 3665                     NaN                 NaN
# 3668                     NaN                   W
# 3671                     NaN                 NaN
# 3673                     NaN                 NaN
# 3677                     NaN                 NaN
# 3680                     NaN                 NaN
# 3681                     NaN                 NaN
# 3684                     NaN                   W
# 3687                     NaN                 NaN
# 3692                     NaN                 NaN
# 3697                     NaN                   W
# 3701                     NaN                 NaN
# 3704                     NaN                 NaN
# 3705                     NaN                 NaN
# 3706                     NaN                 NaN
#
#                                               FOOTNOTES
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 10                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 21                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 28                                                  NaN
# 36    # Avery Vise withdrew after the primary electi...
# 38                                                  NaN
# 41                                                  NaN
# 44                                                  NaN
# 50                                                  NaN
# 55                                                  NaN
# 58                                                  NaN
# 60                                                  NaN
# 66                                                  NaN
# 67                                                  NaN
# 68                                                  NaN
# 69                                                  NaN
# 70                                                  NaN
# 71                                                  NaN
# 72                                                  NaN
# ...                                                 ...
# 3612                                                NaN
# 3615                                                NaN
# 3618                                                NaN
# 3620                                                NaN
# 3625                                                NaN
# 3628                                                NaN
# 3632                                                NaN
# 3638                                                NaN
# 3639                                                NaN
# 3642                                                NaN
# 3645                                                NaN
# 3650                                                NaN
# 3653                                                NaN
# 3659                                                NaN
# 3662                                                NaN
# 3665                                                NaN
# 3668                                                NaN
# 3671                                                NaN
# 3673                                                NaN
# 3677                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3684                                                NaN
# 3687                                                NaN
# 3692                                                NaN
# 3697                                                NaN
# 3701                                                NaN
# 3704                                                NaN
# 3705                                                NaN
# 3706                                                NaN
#
# [1369 rows x 22 columns]

# %% [markdown]
# **Part B**: Complete the function winners_and_margins( ) that takes in your clean DataFrame from **Part A** and returns a DataFrame with one row per state-district pair and with columns **STATE**, **D**, **WINNER**, and **MARGIN** where
#
# - **STATE** and **D** are as defined in the original DataFrame
# <p> </p>
# - **WINNER** is the name of the candidate that had the largest general vote percentage (which may possibly be "UNKNOWN")
# <p> </p>
# - **MARGIN** is the difference between the winning general vote percentage and the second highest vote percentage.  If there is only one candidate in a particular district you should list the general vote percentage obtained by the sole candidate.
#
# <p> </p>
#
# Finally, your DataFrame should be **sorted from most contentious races to least contentious** (i.e. from smallest winning margin to the largest).

# %%
def winners_and_margins(df):
    
    return dfWinners
